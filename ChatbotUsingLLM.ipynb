# %%
from langchain_openai import ChatOpenAI
from langgraph.graph import StateGraph, START, END
from typing import TypedDict, Literal
# Out:
# d:\Langgraph\.venv\Lib\site-packages\langgraph\cache\base\__init__.py:8: LangChainPendingDeprecationWarning: The default value of `allowed_objects` will change in a future version. Pass an explicit value (e.g., allowed_objects='messages' or allowed_objects='core') to suppress this warning.
#   from langgraph.checkpoint.serde.jsonplus import JsonPlusSerializer

# %%
class ChatBot(TypedDict):
    user_input: str 
    bot_response: str

# %%
model = ChatOpenAI(model="gpt-3.5-turbo", temperature=0.9)

# %%
def get_response(state: ChatBot) -> ChatBot:
    user_input = state["user_input"]
    state["bot_response"] = model.invoke(user_input)
    return state

# %%
graph = StateGraph(ChatBot)

graph.add_node("get_response", get_response)

graph.add_edge(START, "get_response")
graph.add_edge("get_response", END)

workflow = graph.compile()
workflow
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File d:\Langgraph\.venv\Lib\site-packages\urllib3\connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
# --> 464     self._validate_conn(conn)
#     465 except (SocketTimeout, BaseSSLError) as e:
#
# File d:\Langgraph\.venv\Lib\site-packages\urllib3\connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File d:\Langgraph\.venv\Lib\site-packages\urllib3\connection.py:796, in HTTPSConnection.connect(self)
#     794 server_hostname_rm_dot = server_hostname.rstrip(".")
# ...

# %%
print("ChatBot is Ready! Type 'exit' or 'quit' to stop the chatbot.")
while True:
    user_input = input("You: ")
    if user_input.lower() in ["exit", "quit"]:
        print("Exiting the chatbot. Goodbye!")
        break
    workflow.invoke({"user_input": user_input})
# Out:
# ChatBot is Ready! Type 'exit' or 'quit' to stop the chatbot.
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File d:\Langgraph\.venv\Lib\site-packages\httpx\_transports\default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File d:\Langgraph\.venv\Lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File d:\Langgraph\.venv\Lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
# ...
