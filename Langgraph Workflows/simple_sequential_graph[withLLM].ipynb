# %%
from langgraph.graph import START, END, StateGraph
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from typing import TypedDict
# Out:
# f:\Langgraph\myenv\Lib\site-packages\langgraph\cache\base\__init__.py:8: LangChainPendingDeprecationWarning: The default value of `allowed_objects` will change in a future version. Pass an explicit value (e.g., allowed_objects='messages' or allowed_objects='core') to suppress this warning.
#   from langgraph.checkpoint.serde.jsonplus import JsonPlusSerializer

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatOpenAI()

# %%
class SimpleChatState(TypedDict):
    user_input: str
    bot_response: str

# %%
def processing(state: SimpleChatState) -> SimpleChatState:
    user_input = state['user_input']
    
    prompt = f"Answer the following question: {user_input}"
    
    response = model.invoke(prompt)
    
    state['bot_response'] = response.content
    
    return state

# %%
graph = StateGraph(SimpleChatState)

graph.add_node("output_generate", processing)

graph.add_edge(START, "output_generate")
graph.add_edge("output_generate", END)

workflow = graph.compile()

# %%
response = workflow.invoke({"user_input": "What is difference between cpu and vcpu?"})
response
# Out:
# {'user_input': 'What is difference between cpu and vcpu?',
#  'bot_response': 'The main difference between a CPU and a vCPU is that a CPU (Central Processing Unit) refers to the physical processor that is located on the motherboard of a computer, while a vCPU (Virtual CPU) is a virtual processor that is configured within a virtualized environment such as a virtual machine. \n\nA CPU is a physical hardware component that executes instructions and processes data within a computer system, while a vCPU is a software-based version of a CPU that is allocated to virtual machines to enable them to run multiple operating systems and applications simultaneously. Multiple vCPUs can be allocated to a single physical CPU depending on the virtualization platform and configuration settings.'}
